# %%
#2015_고등교육기관_일람표
#https://www.data.go.kr/dataset/3038867/fileData.do

import csv
import datetime

# 파일 내용 읽어오기
file_name="2015univ.csv"
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file)  #한줄 한줄 읽는다
data = list(csv_file)  #다음줄을 목록화한다
file.close()

sorted(data, key=len)

# 파일 내용 출력하기
for row in data :
    print(row)
# Out:
# ['201501', '전문대학', '71006000', '한국철도대학', '본교', '폐교', '경기', '국립', '437-763', '경기도 의왕시 철도박물관로 157 (월암동, 한국교통대학교)', '180', '134', '46', '0']
# ['201501', '전문대학', '72001000', '강원도립대학', '본교', '기존', '강원', '공립', '210-804', '강원도 강릉시 연주로 270 (주문진읍, 강원도립대학)', '1658', '900', '758', '31']
# ['201501', '전문대학', '72002000', '경남도립거창대학', '본교', '기존', '경남', '공립', '670-804', '경남 거창군 거창읍 거창대학로 72', '1614', '955', '659', '31']
# ['201501', '전문대학', '72003000', '경남도립남해대학', '본교', '기존', '경남', '공립', '668-801', '경남 남해군 남해읍 화전로 78번길 30', '1639', '846', '793', '25']
# ['201501', '전문대학', '72005000', '경북도립대학교', '본교', '기존', '경북', '공립', '757-807', '경북 예천군 예천읍 도립대학길 114', '1389', '930', '459', '32']
# ['201501', '전문대학', '72006000', '충북도립대학', '본교', '기존', '충북', '공립', '373-807', '충북 옥천군 옥천읍 대학길 15', '1815', '1028', '787', '30']
# ['201501', '전문대학', '72007000', '인천전문대학', '본교', '폐교', '인천', '공립', '402-750', '인천 남구 석정로 165(도화동 193-6)', '0', '0', '0', '0']
# ...

# %%
#2015_고등교육기관_일람표
import csv
import datetime

# 파일 내용 읽어오기
file_name="2015univ.csv"
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file)  #한줄 한줄 읽는다
data = list(csv_file)  #다음줄을 목록화한다
file.close()

# 학제 분류 출력하기
academic = []
for row in data :
    if row[1] not in academic : 
        academic.append(row[1])

for a in academic :
    print(a)
# Out:
# 전문대학
# 교육대학
# 대학교
# 방송통신대학
# 산업대학
# 기술대학
# 각종대학(전문)
# 각종대학(대학)
# 원격대학(전문)
# 원격대학(대학)
# 사내대학(전문)
# 사내대학(대학)
# 사이버대학(대학)
# 사이버대학(전문)
# 전공대학
# 기능대학
# 대학원대학
# 대학부설대학원

# %%
#2015_고등교육기관_일람표
import csv
import datetime

# 파일 내용 읽어오기
file_name='2015univ.csv'
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file) # 한줄 한줄 읽는다
data = list(csv_file)   # 다음줄을 목록화 한다
file.close()

# 대학 휴학생비율, 교수1인당 학생수 
academic = []
for row in data :
    if row[5]=='기존' and int(row[13])!=0 and int(row[10])!=0 :
        if row[1] in ['대학교'] : 
            #[0대학분류,1대학이름,2재적학생수,3재학생수,4휴학생수,5교수수]
            #academic.append([row[1],row[3],int(row[10]),int(row[11]),int(row[12]),int(row[13])])
            #[0대학분류,1대학이름,2본분교,3휴학생비율(휴학생수/재적학생수),4(재적학생수/교수수),5(재학생수/교수수)]
            academic.append([row[1],row[3],row[4],(int(row[12])/int(row[10])),(int(row[10])/int(row[13])),(int(row[11])/int(row[13]))])

academic.sort()

for a in academic :
    print(a)
# Out:
# ['대학교', '가야대학교', '본교', 0.21253731343283583, 34.183673469387756, 26.918367346938776]
# ['대학교', '가천대학교', '본교', 0.2801862860171898, 40.63230769230769, 29.247692307692308]
# ['대학교', '가톨릭관동대학교', '본교', 0.34112250017919865, 30.933481152993348, 20.38137472283814]
# ['대학교', '가톨릭대학교', '본교', 0.2746215844309023, 41.19028340080972, 29.87854251012146]
# ['대학교', '가톨릭대학교', '제2캠퍼스', 0.040169133192389, 0.5455594002306805, 0.5236447520184544]
# ['대학교', '가톨릭대학교', '제3캠퍼스', 0.35231316725978645, 12.217391304347826, 7.913043478260869]
# ['대학교', '감리교신학대학교', '본교', 0.27411167512690354, 40.758620689655174, 29.586206896551722]
# ['대학교', '강남대학교', '본교', 0.27355289421157686, 45.13513513513514, 32.788288288288285]
# ['대학교', '강릉원주대학교', '본교', 0.3084543510075425, 30.52577319587629, 21.10996563573883]
# ['대학교', '강릉원주대학교', '제2캠퍼스', 0.29092136348295644, 33.29213483146067, 23.60674157303371]
# ['대학교', '강원대학교', '본교', 0.3310810810810811, 35.23809523809524, 23.571428571428573]
# ...

# %%
#2015_고등교육기관_일람표
import csv
import datetime

# 파일 내용 읽어오기
file_name='2015univ.csv'
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file) # 한줄 한줄 읽는다
data = list(csv_file)   # 다음줄을 목록화 한다
file.close()

# 학제 분류 출력하기 
academic = []
student = []
for row in data :
    if row[5]=='기존' and int(row[13])!=0 and int(row[10])!=0 :
        if row[1] in ['대학교'] : 
            #[0대학분류,1대학이름,2재적학생수,3재학생수,4휴학생수,5교수수]
            #academic.append([row[1],row[3],int(row[10]),int(row[11]),int(row[12]),int(row[13])])
            #[0대학분류,1대학이름,2휴학생비율(휴학생수/재적학생수),3(재적학생수/교수수),4(재학생수/교수수)]
            academic.append([row[1],row[3],(int(row[12])/int(row[10])),(int(row[10])/int(row[13])),(int(row[11])/int(row[13]))])

            student.append([(int(row[12])/int(row[10])),row[3]])
academic.sort()
student.sort(reverse=True)
#for a in academic :
#    print(a)
#휴학생 비율이 높은 학교
print('<휴학생 비율>')
for a in student :
    print(a[1], str(int(a[0]*100))+'%')
# Out:
# <휴학생 비율>
# 대신대학교 47%
# 서남대학교 47%
# 강원대학교 40%
# 신경대학교 39%
# 영동대학교 36%
# 경주대학교 36%
# 대전가톨릭대학교 36%
# 제주대학교 35%
# 가톨릭대학교 35%
# 안동대학교 35%
# 중부대학교 34%
# 전남대학교 34%
# 울산대학교 34%
# 가톨릭관동대학교 34%
# 광주가톨릭대학교 34%
# 중앙대학교 안성캠퍼스 33%
# 경남대학교 33%
# 세한대학교 33%
# 조선대학교 33%
# 원광대학교 33%
# 강원대학교 33%
# 한국산업기술대학교 32%
# 동명대학교 32%
# 부산외국어대학교 32%
# 금강대학교 32%
# 고려대학교 세종캠퍼스 32%
# 경동대학교 32%
# 경기대학교 32%
# 금오공과대학교 32%
# 세명대학교 32%
# 청주대학교 32%
# 인천가톨릭대학교 31%
# 영남대학교 31%
# 명지대학교 자연캠퍼스 31%
# 한국항공대학교 31%
# 전주대학교 31%
# 인하대학교 31%
# 한라대학교 31%
# 경동대학교 31%
# 상지대학교 31%
# 건국대학교 31%
# 계명대학교 30%
# 호남신학대학교 30%
# 숭실대학교 30%
# 강릉원주대학교 30%
# 한국교통대학교 30%
# 명지대학교 인문캠퍼스 30%
# 동의대학교 30%
# 대구대학교 30%
# 수원가톨릭대학교 30%
# 한남대학교 30%
# 건국대학교 30%
# 한국기술교육대학교 30%
# 동아대학교 30%
# 용인대학교 30%
# 광운대학교 30%
# 경남과학기술대학교 30%
# 동국대학교 30%
# 한경대학교 30%
# 안양대학교 30%
# 한성대학교 30%
# 대구예술대학교 30%
# 한밭대학교 30%
# 창원대학교 29%
# 목포대학교 29%
# 경성대학교 29%
# 경운대학교 29%
# 대구외국어대학교 29%
# 경기대학교 29%
# 한신대학교 29%
# 동양대학교 29%
# 홍익대학교 세종캠퍼스 29%
# 아주대학교 29%
# 대전대학교 29%
# 단국대학교 29%
# 세종대학교 29%
# ...

# %%
#2015_고등교육기관_일람표
import csv
import datetime

# 파일 내용 읽어오기
file_name='2015univ.csv'
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file) # 한줄 한줄 읽는다
data = list(csv_file)   # 다음줄을 목록화 한다
file.close()

# 학제 분류 출력하기 
academic = []
professor = []
for row in data :
    if row[5]=='기존' and int(row[13])!=0 and int(row[10])!=0 :
        if row[1] in ['대학교'] : 
            #[0대학분류,1대학이름,2재적학생수,3재학생수,4휴학생수,5교수수]
            #academic.append([row[1],row[3],int(row[10]),int(row[11]),int(row[12]),int(row[13])])
            #[0대학분류,1대학이름,2휴학생비율(휴학생수/재적학생수),3(재적학생수/교수수),4(재학생수/교수수)]
            academic.append([row[1],row[3],(int(row[12])/int(row[10])),(int(row[10])/int(row[13])),(int(row[11])/int(row[13]))])
            professor.append([(int(row[10])/int(row[13])),row[3]])

professor.sort()
#교수 1인당 학생수가 낮은 학교
print('<교수 1인당 학생수>')
for a in professor :

    
    print(a[1], str(int(a[0]))+'명')
# Out:
# <교수 1인당 학생수>
# 가톨릭대학교 0명
# 인제대학교  1명
# 을지대학교 3명
# 영산선학대학교 3명
# 인천가톨릭대학교 6명
# 서남대학교 7명
# 포항공과대학교 7명
# 광주가톨릭대학교 8명
# 대전가톨릭대학교 8명
# 한국과학기술원 9명
# 서울대학교 11명
# 가톨릭대학교 12명
# 광신대학교 13명
# 한려대학교 13명
# 중앙승가대학교 13명
# 부산장신대학교 13명
# 서남대학교 13명
# 장로회신학대학교 13명
# 한국교원대학교 14명
# 예원예술대학교 14명
# 한림대학교 14명
# 수원가톨릭대학교 15명
# 울산과학기술대학교 16명
# 건양대학교 17명
# 제주국제대학교 17명
# 순천향대학교 17명
# 서울장신대학교 17명
# 연세대학교 17명
# 울산대학교 18명
# 대신대학교 18명
# 고신대학교 18명
# 영남신학대학교 19명
# 호남신학대학교 20명
# 총신대학교 20명
# 세한대학교 21명
# 대전신학대학교 22명
# 성균관대학교 22명
# 한영신학대학교 22명
# 아주대학교 22명
# 한양대학교 22명
# 한일장신대학교 23명
# 고려대학교 23명
# 경운대학교 24명
# 한중대학교 24명
# 전남대학교 24명
# 예수대학교 25명
# 금강대학교 25명
# 송원대학교 26명
# 경주대학교 26명
# 광주과학기술원 26명
# 단국대학교 27명
# 이화여자대학교 27명
# 꽃동네대학교 27명
# 한국전통문화대학교 27명
# 중앙대학교 서울캠퍼스 27명
# 한국성서대학교 28명
# 루터대학교 28명
# 충북대학교 28명
# 목포해양대학교 28명
# 한국체육대학교 28명
# 대구외국어대학교 28명
# 창신대학교 29명
# 아세아연합신학대학교 29명
# 전남대학교 29명
# 중원대학교 29명
# 연세대학교 원주캠퍼스 29명
# 한세대학교 29명
# 남서울대학교 29명
# 신경대학교 29명
# 서강대학교 30명
# 동국대학교 30명
# 광주여자대학교 30명
# 대구가톨릭대학교 30명
# 강릉원주대학교 30명
# ...

# %%
#http://colorscripter.com/s/S1hnCEj
# 2018.1.25 @sohi

# 대학의 휴학생비율과 교수1인당 학생수를 검색하는 프로그램이다.
# 대학을 선택할 때 참고자료가 될 수 있다.
# 고등학생이 관심 있게 프로그래밍 할 수 있는 자료를 찾게 되었다.

# 2015_고등교육기관_일람표
# https://www.data.go.kr/dataset/3038867/fileData.do
# 엑셀 파일을 수정 - 제목을 한행으로, 수치데이터 셀을 숫자로 변경한 csv파일 사용


import csv
import datetime

# 파일 내용 읽어오기
file_name='2015univ.csv'
file = open(file_name,'r',encoding='utf8')
csv_file = csv.reader(file)

header = next(csv_file) # 한줄 한줄 읽는다
data = list(csv_file)   # 다음줄을 목록화 한다
file.close()

# 학교 입력
school = input('학교명을 입력하세요 : (ex 조선대학교 한양대학교)').split()

s1 = 0 #재적학생수 int(row[10])
s2 = 0 #재학생수 int(row[11])
s3 = 0 #휴학생수 int(row[12])
p = 0 #교수수 int(row[13])

for s in school :
    for row in data :
        if s==row[3] and row[5]=='기존' and int(row[13])!=0 and int(row[10])!=0 :
            #본교, 분교1, 제2캠퍼스 등은 하나로 합쳐야 함
            s1 = s1 + int(row[10])
            s2 = s2 + int(row[11])
            s3 = s3 + int(row[12])
            p = p + int(row[13])
    
    print(s + ': 휴학생 비율='+str(int(s3/s1*100))+'%' #휴학생비율 = 휴학생수/재적학생수
          + ', 교수1인당 학생수='+str(int(s1/p))+'명('  #교수1인당 학생수 = 재적학생수/교수수
          +str(int(s2/p))+'명)')  #교수1인당 학생수 = 재학생수/교수수
    s1 = s2 = s3 = p = 0
# Out:
# 조선대학교: 휴학생 비율=33%, 교수1인당 학생수=35명(23명)
# 한양대학교: 휴학생 비율=28%, 교수1인당 학생수=25명(18명)
